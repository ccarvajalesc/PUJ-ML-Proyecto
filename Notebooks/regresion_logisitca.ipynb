# %%
# %pip install scikit-learn==1.7.2
# Out:
# Requirement already satisfied: scikit-learn==1.7.2 in /home/mruizm/miniconda3/envs/base_311/lib/python3.11/site-packages (1.7.2)
# Requirement already satisfied: numpy>=1.22.0 in /home/mruizm/miniconda3/envs/base_311/lib/python3.11/site-packages (from scikit-learn==1.7.2) (1.26.4)
# Requirement already satisfied: scipy>=1.8.0 in /home/mruizm/miniconda3/envs/base_311/lib/python3.11/site-packages (from scikit-learn==1.7.2) (1.17.1)
# Requirement already satisfied: joblib>=1.2.0 in /home/mruizm/miniconda3/envs/base_311/lib/python3.11/site-packages (from scikit-learn==1.7.2) (1.5.3)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /home/mruizm/miniconda3/envs/base_311/lib/python3.11/site-packages (from scikit-learn==1.7.2) (3.6.0)
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# # Notebook de procesamiento de datos

# %%
# ── Librerías estándar ────────────────────────────────────────────────────────
import os
import time
import warnings
import json
from collections import Counter

# ── Datos ────────────────────────────────────────────────────────────────────
import numpy as np
import pandas as pd

# ── Visualización ─────────────────────────────────────────────────────────────
import matplotlib.pyplot as plt
import seaborn as sns
from IPython.display import display

# ── Scikit-learn ──────────────────────────────────────────────────────────────
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import (
    OrdinalEncoder, StandardScaler, LabelEncoder, OneHotEncoder
)
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.impute import SimpleImputer
from sklearn.base import clone
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import (
    accuracy_score, classification_report, confusion_matrix,
    roc_auc_score, f1_score, precision_score, recall_score
)
from sklearn.utils.class_weight import compute_class_weight
import sklearn

# ── XGBoost ───────────────────────────────────────────────────────────────────
#from xgboost import XGBClassifier
#import xgboost as xgb

# ── TensorFlow / Keras ────────────────────────────────────────────────────────
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers, callbacks

# ── API Socrata ───────────────────────────────────────────────────────────────
from sodapy import Socrata

# ── Configuraciones globales ──────────────────────────────────────────────────
warnings.filterwarnings('ignore')
pd.set_option('display.max_columns', 60)
pd.set_option('display.float_format', '{:.4f}'.format)
np.random.seed(42)
tf.random.set_seed(42)

sns.set_theme(style='whitegrid', palette='Set2', font_scale=1.1)
plt.rcParams.update({'figure.dpi': 110, 'figure.figsize': (10, 5)})

print('✅ Entorno configurado.')
print(f'   NumPy:       {np.__version__}')
print(f'   Pandas:      {pd.__version__}')
#print(f'   XGBoost:     {xgb.__version__}')
print(f'   TensorFlow:  {tf.__version__}')
print(f'   sklearn:     {sklearn.__version__}')
# Out:
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1780111589.141501   45639 port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# I0000 00:00:1780111589.177734   45639 cpu_feature_guard.cc:227] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI AVX512_BF16 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1780111590.482120   45639 port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# ✅ Entorno configurado.
#    NumPy:       1.26.4
#    Pandas:      2.3.3
#    TensorFlow:  2.21.0
#    sklearn:     1.7.2

# %%
# ── Parámetros de descarga ────────────────────────────────────────────────────
DATASET_ID = 'kgxf-xxbe'
PAGE_SIZE  = 10_000
RAW_PATH   = 'saber11_20221_20224.parquet'
PERIODOS   = ['20221', '20224']   # ÚNICAMENTE estos dos períodos

print(f'Dataset ID : {DATASET_ID}')
print(f'Page size  : {PAGE_SIZE:,} registros/bloque')
print(f'Caché path : {RAW_PATH}')
print(f'Períodos   : {PERIODOS}')
# Out:
# Dataset ID : kgxf-xxbe
# Page size  : 10,000 registros/bloque
# Caché path : saber11_20221_20224.parquet
# Períodos   : ['20221', '20224']

# %%
# ── Descarga paginada por período ────────────────────────────────────────────
if os.path.exists(RAW_PATH):
    print(f'📂 Cargando desde caché: {RAW_PATH}')
    df_raw = pd.read_parquet(RAW_PATH)
else:
    print('🌐 Conectando a la API de datos.gov.co...')
    client = Socrata(
        'www.datos.gov.co',
        None,          # acceso anónimo (lectura pública)
        timeout=300
    )
    all_records = []

    for periodo in PERIODOS:
        print(f'\n📥 Descargando período {periodo}...')
        offset, total_periodo = 0, 0

        while True:
            try:
                batch = client.get(
                    DATASET_ID,
                    where=f"periodo = '{periodo}'",
                    limit=PAGE_SIZE,
                    offset=offset
                )
            except Exception as e:
                print(f'⚠️  Error en offset {offset}: {e} — reintentando en 5 s...')
                time.sleep(5)
                batch = client.get(
                    DATASET_ID,
                    where=f"periodo = '{periodo}'",
                    limit=PAGE_SIZE,
                    offset=offset
                )

            if not batch:
                print(f'✅ Fin de descarga para {periodo}')
                break

            all_records.extend(batch)
            batch_size     = len(batch)
            total_periodo += batch_size
            offset        += PAGE_SIZE

            print(f'   ✔ {periodo} | batch={batch_size:,} | acum={total_periodo:,}')

            if batch_size < PAGE_SIZE:
                print(f'✅ Último bloque para {periodo}')
                break
            time.sleep(0.5)

    df_raw = pd.DataFrame.from_records(all_records)
    df_raw.to_parquet(RAW_PATH, index=False)
    print(f'\n✅ {len(df_raw):,} registros guardados en "{RAW_PATH}"')

# ── Resumen ───────────────────────────────────────────────────────────────────
print(f'\n📊 Dimensiones: {df_raw.shape[0]:,} filas × {df_raw.shape[1]} columnas')
print('\n📌 Registros por período:')
display(
    df_raw['periodo']
    .value_counts()
    .sort_index(ascending=False)
    .rename('Registros')
    .to_frame()
    .assign(Porcentaje_pct=lambda x: (x['Registros'] / x['Registros'].sum() * 100).round(2))
)
# Out:
# 📂 Cargando desde caché: saber11_20221_20224.parquet
#
# 📊 Dimensiones: 1,085,937 filas × 51 columnas
#
# 📌 Registros por período:
#          Registros  Porcentaje_pct
# periodo
# 20224      1065888         98.1500
# 20221        20049          1.8500

# %% [markdown]
# ## Definición de variables objetivo

# %%
# ── Variable objetivo ────────────────────────────────────────────────────────
df = df_raw.copy()
df['punt_global'] = pd.to_numeric(df['punt_global'], errors='coerce')

#LABELS = ['Muy Bajo', 'Bajo', 'Aceptable', 'Bueno', 'Excelente']
#BINS   = [0, 232, 270, 310, 360, 500]

LABELS = ['Bajo', 'Básico', 'Alto']
BINS   = [0, 225, 335, 500]

#LABELS = ['Bajo', 'Alto']
#BINS   = [0, 250, 500]


df['nivel_desempeno'] = pd.cut(
    df['punt_global'], bins=BINS, labels=LABELS,
    include_lowest=True, right=True
)

print('✅ Variable objetivo creada: nivel_desempeno')
dist = df['nivel_desempeno'].value_counts().reindex(LABELS)
pct  = (dist / dist.sum() * 100).round(2)
display(pd.DataFrame({'Clase': LABELS, 'Conteo': dist.values, '% Total': pct.values}))
# Out:
# ✅ Variable objetivo creada: nivel_desempeno
#     Clase  Conteo  % Total
# 0    Bajo  383754  35.3400
# 1  Básico  634657  58.4400
# 2    Alto   67526   6.2200

# %%
# ── Visualización del balance de clases ──────────────────────────────────────
#COLORES = ['#E74C3C', '#E67E22', '#F1C40F', '#2ECC71', '#3498DB']
COLORES = ['#E74C3C', '#E67E22', '#F1C40F']

fig, axes = plt.subplots(1, 2, figsize=(13, 5))

# Barras
dist.plot(kind='bar', ax=axes[0], color=COLORES, edgecolor='white')
axes[0].set_title('Distribución de Niveles de Desempeño',
                  fontsize=12, fontweight='bold')
axes[0].set_xlabel('Nivel'); axes[0].set_ylabel('Estudiantes')
axes[0].tick_params(axis='x', rotation=15)
total_p = dist.sum()
for bar in axes[0].patches:
    axes[0].text(
        bar.get_x() + bar.get_width()/2,
        bar.get_height() + total_p * 0.003,
        f'{bar.get_height():,}\n({bar.get_height()/total_p*100:.1f}%)',
        ha='center', fontsize=8
    )

# Pie
dist.plot(kind='pie', ax=axes[1], autopct='%1.1f%%',
          colors=COLORES, startangle=90, textprops={'fontsize': 10})
axes[1].set_title('Proporción de Clases', fontsize=12, fontweight='bold')
axes[1].set_ylabel('')

plt.suptitle('Balance de Clases — Variable Objetivo', fontsize=13, fontweight='bold')
plt.tight_layout()
plt.savefig('images/fig_balance_clases.png', dpi=110, bbox_inches='tight')
plt.show()

# %%
# ── Definición de columnas ────────────────────────────────────────────────────
SCORE_COLS = [c for c in ['punt_ingles','punt_matematicas','punt_c_naturales',
                            'punt_sociales_ciudadanas','punt_lectura_critica','punt_global']
              if c in df_raw.columns]

EXCLUDE_COLS = SCORE_COLS + [
    'estu_consecutivo',
    'periodo',
    'nivel_desempeno',
    'cole_cod_depto_ubicacion',

    # =========================
    # Variables adicionales
    # =========================
    'estu_tipodocumento',
    'cole_cod_mcpio_ubicacion',
    'cole_cod_departamento_unicacion',
    'cole_codigo_icfes',
    'cole_nombre_establecimiento',
    'cole_nombre_sede',
    'estu_cod_depto_presentacion',
    'estu_cod_mcpio_presentacion',
    'estu_cod_reside_mcpio',
    'estu_fechanacimiento',
    'estu_mcpio_presentacion',
    'estu_mcpio_reside',
    'estu_pais_reside',
    'desemp_ingles',
    'cole_mcpio_ubicacion',
    'cole_codigo_icfes',
    'cole_cod_dane_sede',
    'cole_cod_dane_establecimiento',
    'estu_cod_mcpio_presentacion'
]


TARGET       = 'nivel_desempeno'

# Excluir variables de alta cardinalidad (>200 categorías → problemas de memoria/encoding)
alta_card = []
for col in df.columns:
    if col not in EXCLUDE_COLS and df[col].dtype == object:
        if df[col].nunique() > 200:
            alta_card.append(col)
            EXCLUDE_COLS.append(col)

if alta_card:
    print(f'⚠️  Excluidas por alta cardinalidad (>{200} cat.): {alta_card}')

FEATURES     = [c for c in df.columns if c not in EXCLUDE_COLS]
NUM_FEATURES = df[FEATURES].select_dtypes(include='number').columns.tolist()
CAT_FEATURES = df[FEATURES].select_dtypes(include=['object','category']).columns.tolist()

print(f'\nTotal features: {len(FEATURES)}')
print(f'  → Numéricas  : {len(NUM_FEATURES)} → {NUM_FEATURES}')
print(f'  → Categóricas: {len(CAT_FEATURES)} → {CAT_FEATURES}')
# Out:
# Total features: 26
#   → Numéricas  : 0 → []
#   → Categóricas: 26 → ['cole_area_ubicacion', 'cole_calendario', 'cole_caracter', 'cole_depto_ubicacion', 'cole_genero', 'cole_jornada', 'cole_naturaleza', 'cole_sede_principal', 'estu_cod_reside_depto', 'estu_depto_presentacion', 'estu_depto_reside', 'estu_estadoinvestigacion', 'estu_estudiante', 'estu_genero', 'estu_nacionalidad', 'estu_privado_libertad', 'fami_cuartoshogar', 'fami_educacionmadre', 'fami_educacionpadre', 'fami_estratovivienda', 'fami_personashogar', 'fami_tieneautomovil', 'fami_tienecomputador', 'fami_tieneinternet', 'fami_tienelavadora', 'cole_bilingue']

# %% [markdown]
# ### 5.3 Limpieza Pre-Modelado: Duplicados y Registros Sin Target

# %%
# ── Eliminar duplicados (estu_consecutivo) ────────────────────────────────────
n_antes = len(df)
df = df[~df.duplicated(subset=['estu_consecutivo'], keep='first')].reset_index(drop=True)
print(f'Registros eliminados por duplicado: {n_antes - len(df):,}')

# ── Eliminar filas sin nivel_desempeno (sin punt_global válido) ────────────────
df = df.dropna(subset=['nivel_desempeno']).reset_index(drop=True)
print(f'Registros con target válido: {len(df):,}')

# ── Codificación numérica del target ──────────────────────────────────────────
label2idx = {l: i for i, l in enumerate(LABELS)}
df['target'] = df['nivel_desempeno'].map(label2idx)

print('\nCodificación del target:')
for l, i in label2idx.items():
    print(f'  {i} → {l}')
# Out:
# Registros eliminados por duplicado: 533,096
# Registros con target válido: 552,841
#
# Codificación del target:
#   0 → Bajo
#   1 → Básico
#   2 → Alto

# %% [markdown]
# ## Para dos experimentos de eliminación e imputación

# %%
# ── Subsets por experimento ───────────────────────────────────────────────────
X_all = df[FEATURES].copy()
y_all = df['target'].copy()

# Experimento 1: solo filas completamente limpias
mask_clean = X_all.notna().all(axis=1)
X_exp1, y_exp1 = X_all[mask_clean].reset_index(drop=True), y_all[mask_clean].reset_index(drop=True)

# Experimento 2: dataset completo (con nulos — se imputará en el pipeline)
X_exp2, y_exp2 = X_all.copy(), y_all.copy()

print(f'Exp 1 (Eliminación): {len(X_exp1):,} registros ({len(X_exp1)/len(X_all)*100:.1f}%)')
print(f'Exp 2 (Imputación):  {len(X_exp2):,} registros ({len(X_exp2)/len(X_all)*100:.1f}%)')
# Out:
# Exp 1 (Eliminación): 406,448 registros (73.5%)
# Exp 2 (Imputación):  552,841 registros (100.0%)

# %%
# ── División Train / Test estratificada (80/20) ────────────────────────────────
RANDOM_STATE = 42

X_tr1, X_te1, y_tr1, y_te1 = train_test_split(
    X_exp1, y_exp1, test_size=0.20, random_state=RANDOM_STATE, stratify=y_exp1
)
X_tr2, X_te2, y_tr2, y_te2 = train_test_split(
    X_exp2, y_exp2, test_size=0.20, random_state=RANDOM_STATE, stratify=y_exp2
)

print('División Train / Test (80/20, estratificada):')
print(f'  Exp 1 → Train: {len(X_tr1):,}  |  Test: {len(X_te1):,}')
print(f'  Exp 2 → Train: {len(X_tr2):,}  |  Test: {len(X_te2):,}')
# Out:
# División Train / Test (80/20, estratificada):
#   Exp 1 → Train: 325,158  |  Test: 81,290
#   Exp 2 → Train: 442,272  |  Test: 110,569

# %%
# Experimento 1: sin imputación (datos ya limpios)
proc_e1 = ColumnTransformer([
    ('num', StandardScaler(), NUM_FEATURES),
    ('cat', OneHotEncoder(handle_unknown='ignore'), CAT_FEATURES)
], remainder='drop')

# Experimento 2: con imputación antes de escalar/codificar
proc_e2 = ColumnTransformer([
    ('num', Pipeline([
        ('imp', SimpleImputer(strategy='median')),
        ('sc',  StandardScaler())
    ]), NUM_FEATURES),

    ('cat', Pipeline([
        ('imp', SimpleImputer(strategy='most_frequent')),
        ('enc', OneHotEncoder(handle_unknown='ignore'))
    ]), CAT_FEATURES)

], remainder='drop')

print('✅ Preprocesadores definidos.')
print('  Exp 1: StandardScaler + OneHotEncoder (sin imputación)')
print('  Exp 2: SimpleImputer(median/moda) + StandardScaler + OneHotEncoder')
# Out:
# ✅ Preprocesadores definidos.
#   Exp 1: StandardScaler + OneHotEncoder (sin imputación)
#   Exp 2: SimpleImputer(median/moda) + StandardScaler + OneHotEncoder

# %%
def evaluar(nombre, y_true, y_pred, y_prob=None, labels=None):
 
    """

    Calcula y muestra métricas completas de clasificación.

    Compatible con:

    - multiclase

    - binario

    - salidas one-hot/probabilidades

    """
 
    import numpy as np
 
    # ─────────────────────────────────────────────────────────────

    # Normalizar y_true

    # ─────────────────────────────────────────────────────────────

    y_true = np.array(y_true)
 
    # ─────────────────────────────────────────────────────────────

    # Normalizar y_pred

    # ─────────────────────────────────────────────────────────────

    y_pred = np.array(y_pred)
 
    # Caso: predicción tipo one-hot / multilabel

    # Ejemplo: [[0,1],[1,0],...]

    if len(y_pred.shape) > 1:
 
        # Si tiene más de una columna → tomar argmax

        if y_pred.shape[1] > 1:

            y_pred = np.argmax(y_pred, axis=1)
 
        # Si solo tiene una columna

        else:

            y_pred = y_pred.ravel()
 
    # ─────────────────────────────────────────────────────────────

    # Métricas principales

    # ─────────────────────────────────────────────────────────────

    acc  = accuracy_score(y_true, y_pred)
 
    f1m  = f1_score(

        y_true,

        y_pred,

        average='macro',

        zero_division=0

    )
 
    f1w  = f1_score(

        y_true,

        y_pred,

        average='weighted',

        zero_division=0

    )
 
    prec = precision_score(

        y_true,

        y_pred,

        average='macro',

        zero_division=0

    )
 
    rec  = recall_score(

        y_true,

        y_pred,

        average='macro',

        zero_division=0

    )
 
    # ─────────────────────────────────────────────────────────────

    # ROC-AUC

    # ─────────────────────────────────────────────────────────────

    auc = None
 
    if y_prob is not None:
 
        try:
 
            y_prob = np.array(y_prob)
 
            # BINARIO

            if len(np.unique(y_true)) == 2:
 
                # Caso predict_proba -> tomar prob clase positiva

                if len(y_prob.shape) > 1:

                    auc = roc_auc_score(y_true, y_prob[:, 1])

                else:

                    auc = roc_auc_score(y_true, y_prob)
 
            # MULTICLASE

            else:
 
                auc = roc_auc_score(

                    y_true,

                    y_prob,

                    multi_class='ovr',

                    average='macro'

                )
 
        except Exception as e:

            print(f'⚠️ No se pudo calcular ROC-AUC: {e}')
 
    # ─────────────────────────────────────────────────────────────

    # Mostrar métricas

    # ─────────────────────────────────────────────────────────────

    print(f'\n{"═"*58}')

    print(f'  {nombre}')

    print(f'{"═"*58}')
 
    print(f'  Accuracy            : {acc:.4f}')

    print(f'  F1-score (macro)    : {f1m:.4f}')

    print(f'  F1-score (weighted) : {f1w:.4f}')

    print(f'  Precision (macro)   : {prec:.4f}')

    print(f'  Recall (macro)      : {rec:.4f}')
 
    if auc is not None:

        print(f'  ROC-AUC             : {auc:.4f}')
 
    print()
 
    # ─────────────────────────────────────────────────────────────

    # Labels

    # ─────────────────────────────────────────────────────────────

    if labels is None:

        labels = [str(x) for x in sorted(np.unique(y_true))]
 
    print('📋 Classification Report:\n')
 
    print(

        classification_report(

            y_true,

            y_pred,

            target_names=labels,

            zero_division=0

        )

    )
 
    # ─────────────────────────────────────────────────────────────

    # Matriz de confusión

    # ─────────────────────────────────────────────────────────────

    cm = confusion_matrix(y_true, y_pred)
 
    cm_df = pd.DataFrame(

        cm,

        index=[f'Real_{l}' for l in labels],

        columns=[f'Pred_{l}' for l in labels]

    )
 
    print('\n📊 Matriz de Confusión (texto):\n')

    print(cm_df)
 
    fig, ax = plt.subplots(figsize=(7, 5))
 
    sns.heatmap(

        cm,

        annot=True,

        fmt='d',

        cmap='Blues',

        xticklabels=labels,

        yticklabels=labels,

        linewidths=0.4,

        ax=ax

    )
 
    ax.set_title(

        f'Matriz de Confusión — {nombre}',

        fontsize=12,

        fontweight='bold'

    )
 
    ax.set_xlabel('Predicción')

    ax.set_ylabel('Real')
 
    plt.tight_layout()
 
    fn = (

        f'images/confussion_matrix/'

        f'fig_cm_{nombre.replace(" ","_").replace("(","").replace(")","").lower()}.png'

    )
 
    plt.savefig(fn, dpi=110, bbox_inches='tight')
 
    plt.show()
 
    # ─────────────────────────────────────────────────────────────

    # Retorno

    # ─────────────────────────────────────────────────────────────

    return {

        'modelo': nombre,

        'accuracy': acc,

        'f1_macro': f1m,

        'f1_weighted': f1w,

        'precision_macro': prec,

        'recall_macro': rec,

        'roc_auc': auc

    }

# %% [markdown]
# # Experimentos Eliminación (3 tags)

# %%
# ── LR — Exp 1 ───────────────────────────────────────────────────────────────
print('🚀 Regresión Logística — Exp 1 (Eliminación)...')
pipe_lr1 = Pipeline([
    ('prep', proc_e1),
    ('clf',  LogisticRegression(
        max_iter=1000, C=1.0, solver='lbfgs',
        multi_class='multinomial', class_weight='balanced',
        random_state=RANDOM_STATE, n_jobs=-1
    ))
])
pipe_lr1.fit(X_tr1, y_tr1)
yp_lr1   = pipe_lr1.predict(X_te1)
ypr_lr1  = pipe_lr1.predict_proba(X_te1)
met_lr1  = evaluar('LR — Exp 1 (Elim.)', y_te1, yp_lr1, ypr_lr1)
# Out:
# 🚀 Regresión Logística — Exp 1 (Eliminación)...
#
# ══════════════════════════════════════════════════════════
#   LR — Exp 1 (Elim.)
# ══════════════════════════════════════════════════════════
#   Accuracy            : 0.5236
#   F1-score (macro)    : 0.4848
#   F1-score (weighted) : 0.5387
#   Precision (macro)   : 0.4857
#   Recall (macro)      : 0.5948
#   ROC-AUC             : 0.7465
#
# 📋 Classification Report:
#
#               precision    recall  f1-score   support
#
#            0       0.53      0.65      0.58     26071
#            1       0.71      0.43      0.54     49326
#            2       0.22      0.70      0.33      5893
#
#     accuracy                           0.52     81290
#    macro avg       0.49      0.59      0.48     81290
# weighted avg       0.62      0.52      0.54     81290
#
#
# 📊 Matriz de Confusión (texto):
#
#         Pred_0  Pred_1  Pred_2
# Real_0   17016    7176    1879
# Real_1   14970   21443   12913
# Real_2     345    1440    4108

# %%
from sklearn.pipeline import Pipeline
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import GridSearchCV, StratifiedKFold

# ── Pipeline ─────────────────────────────────────────────
pipe_lr = Pipeline([
    ('prep', proc_e1),
    ('clf', LogisticRegression(
        max_iter=3000,
        random_state=RANDOM_STATE,
        multi_class='multinomial'
    ))
])

# ── Grid ─────────────────────────────────────────────────
param_grid = {
    'clf__C': [0.01, 0.1, 1, 10, 100],
    'clf__class_weight': [None, 'balanced'],
    'clf__solver': ['lbfgs', 'newton-cg']
}

# ── CV ───────────────────────────────────────────────────
cv = StratifiedKFold(
    n_splits=5,
    shuffle=True,
    random_state=RANDOM_STATE
)

# ── Grid Search ──────────────────────────────────────────
grid_lr = GridSearchCV(
    estimator=pipe_lr,
    param_grid=param_grid,
    scoring='f1_macro',
    cv=cv,
    n_jobs=4,
    verbose=2,
    return_train_score=True
)

grid_lr.fit(X_tr1, y_tr1)

print("\nMejores parámetros:")
print(grid_lr.best_params_)

print("\nMejor F1 Macro CV:")
print(grid_lr.best_score_)
# Out:
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
#
# Mejores parámetros:
# {'clf__C': 100, 'clf__class_weight': None, 'clf__solver': 'lbfgs'}
#
# Mejor F1 Macro CV:
# 0.494025413643526

# %%
best_lr = grid_lr.best_estimator_

yp_lr = best_lr.predict(X_te1)
ypr_lr = best_lr.predict_proba(X_te1)

met_lr = evaluar(
    'LR GridSearch',
    y_te1,
    yp_lr,
    ypr_lr
)
# Out:
# ══════════════════════════════════════════════════════════
#   LR GridSearch
# ══════════════════════════════════════════════════════════
#   Accuracy            : 0.6691
#   F1-score (macro)    : 0.4938
#   F1-score (weighted) : 0.6382
#   Precision (macro)   : 0.6362
#   Recall (macro)      : 0.4713
#   ROC-AUC             : 0.7595
#
# 📋 Classification Report:
#
#               precision    recall  f1-score   support
#
#            0       0.65      0.40      0.50     26071
#            1       0.68      0.87      0.76     49326
#            2       0.59      0.14      0.22      5893
#
#     accuracy                           0.67     81290
#    macro avg       0.64      0.47      0.49     81290
# weighted avg       0.66      0.67      0.64     81290
#
#
# 📊 Matriz de Confusión (texto):
#
#         Pred_0  Pred_1  Pred_2
# Real_0   10549   15512      10
# Real_1    5728   43039     559
# Real_2      61    5027     805

# %% [markdown]
# # Experimentación inputación (3 tags)

# %%
from sklearn.pipeline import Pipeline
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import GridSearchCV, StratifiedKFold

# ── Pipeline ─────────────────────────────────────────────
pipe_lr = Pipeline([
    ('prep', proc_e2),
    ('clf', LogisticRegression(
        max_iter=3000,
        random_state=RANDOM_STATE,
        multi_class='multinomial'
    ))
])

# ── Grid ─────────────────────────────────────────────────
param_grid = {
    'clf__C': [0.01, 0.1, 1, 10, 100],
    'clf__class_weight': [None, 'balanced'],
    'clf__solver': ['lbfgs', 'newton-cg']
}

# ── CV ───────────────────────────────────────────────────
cv = StratifiedKFold(
    n_splits=5,
    shuffle=True,
    random_state=RANDOM_STATE
)

# ── Grid Search ──────────────────────────────────────────
grid_lr = GridSearchCV(
    estimator=pipe_lr,
    param_grid=param_grid,
    scoring='f1_macro',
    cv=cv,
    n_jobs=4,
    verbose=2,
    return_train_score=True
)

grid_lr.fit(X_tr1, y_tr1)

print("\nMejores parámetros:")
print(grid_lr.best_params_)

print("\nMejor F1 Macro CV:")
print(grid_lr.best_score_)
# Out:
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
#
# Mejores parámetros:
# {'clf__C': 100, 'clf__class_weight': None, 'clf__solver': 'lbfgs'}
#
# Mejor F1 Macro CV:
# 0.494025413643526

# %%
best_lr = grid_lr.best_estimator_

yp_lr = best_lr.predict(X_te1)
ypr_lr = best_lr.predict_proba(X_te1)

met_lr = evaluar(
    'LR GridSearch',
    y_te1,
    yp_lr,
    ypr_lr
)
# Out:
# ══════════════════════════════════════════════════════════
#   LR GridSearch
# ══════════════════════════════════════════════════════════
#   Accuracy            : 0.6691
#   F1-score (macro)    : 0.4938
#   F1-score (weighted) : 0.6382
#   Precision (macro)   : 0.6362
#   Recall (macro)      : 0.4713
#   ROC-AUC             : 0.7595
#
# 📋 Classification Report:
#
#               precision    recall  f1-score   support
#
#            0       0.65      0.40      0.50     26071
#            1       0.68      0.87      0.76     49326
#            2       0.59      0.14      0.22      5893
#
#     accuracy                           0.67     81290
#    macro avg       0.64      0.47      0.49     81290
# weighted avg       0.66      0.67      0.64     81290
#
#
# 📊 Matriz de Confusión (texto):
#
#         Pred_0  Pred_1  Pred_2
# Real_0   10549   15512      10
# Real_1    5728   43039     559
# Real_2      61    5027     805

# %% [markdown]
# Aunque la regresión logística presentó una capacidad de discriminación razonable, evidenciada por el valor de ROC-AUC, el análisis detallado de las métricas por clase muestra dificultades para identificar adecuadamente la categoría de menor frecuencia. En particular, la clase correspondiente al nivel de desempeño más bajo obtuvo un \textit{recall} considerablemente inferior al observado en las demás categorías, lo que redujo el valor global de F1-score macro.
#
# No obstante, los resultados obtenidos permiten establecer una línea base sólida para el problema de clasificación multiclase. El modelo logró capturar una parte importante de la relación existente entre las variables sociodemográficas y el desempeño académico, alcanzando niveles aceptables de precisión global y capacidad de discriminación. Sin embargo, las diferencias observadas entre las métricas de las distintas clases sugieren que el problema presenta un grado de complejidad adicional que podría requerir modelos capaces de representar relaciones más complejas entre las variables predictoras.
#
# En consecuencia, la configuración seleccionada para la regresión logística multinomial corresponde a aquella obtenida mediante \textit{Grid Search}, con (C=100), \texttt{solver=lbfgs} y sin balanceo de clases, la cual alcanzó los mejores resultados globales dentro de las configuraciones evaluadas.

# %%
# ── Variable objetivo ────────────────────────────────────────────────────────
df = df_raw.copy()
df['punt_global'] = pd.to_numeric(df['punt_global'], errors='coerce')

#LABELS = ['Muy Bajo', 'Bajo', 'Aceptable', 'Bueno', 'Excelente']
#BINS   = [0, 232, 270, 310, 360, 500]

#LABELS = ['Bajo', 'Básico', 'Alto']
#BINS   = [0, 225, 335, 500]

LABELS = ['Bajo', 'Alto']
BINS   = [0, 250, 500]


df['nivel_desempeno'] = pd.cut(
    df['punt_global'], bins=BINS, labels=LABELS,
    include_lowest=True, right=True
)

print('✅ Variable objetivo creada: nivel_desempeno')
dist = df['nivel_desempeno'].value_counts().reindex(LABELS)
pct  = (dist / dist.sum() * 100).round(2)
display(pd.DataFrame({'Clase': LABELS, 'Conteo': dist.values, '% Total': pct.values}))


# ── Visualización del balance de clases ──────────────────────────────────────
#COLORES = ['#E74C3C', '#E67E22', '#F1C40F', '#2ECC71', '#3498DB']
COLORES = ['#E74C3C', '#E67E22', '#F1C40F']

fig, axes = plt.subplots(1, 2, figsize=(13, 5))

# Barras
dist.plot(kind='bar', ax=axes[0], color=COLORES, edgecolor='white')
axes[0].set_title('Distribución de Niveles de Desempeño',
                  fontsize=12, fontweight='bold')
axes[0].set_xlabel('Nivel'); axes[0].set_ylabel('Estudiantes')
axes[0].tick_params(axis='x', rotation=15)
total_p = dist.sum()
for bar in axes[0].patches:
    axes[0].text(
        bar.get_x() + bar.get_width()/2,
        bar.get_height() + total_p * 0.003,
        f'{bar.get_height():,}\n({bar.get_height()/total_p*100:.1f}%)',
        ha='center', fontsize=8
    )

# Pie
dist.plot(kind='pie', ax=axes[1], autopct='%1.1f%%',
          colors=COLORES, startangle=90, textprops={'fontsize': 10})
axes[1].set_title('Proporción de Clases', fontsize=12, fontweight='bold')
axes[1].set_ylabel('')

plt.suptitle('Balance de Clases — Variable Objetivo', fontsize=13, fontweight='bold')
plt.tight_layout()
plt.savefig('images/fig_balance_clases.png', dpi=110, bbox_inches='tight')
plt.show()


# ── Definición de columnas ────────────────────────────────────────────────────
SCORE_COLS = [c for c in ['punt_ingles','punt_matematicas','punt_c_naturales',
                            'punt_sociales_ciudadanas','punt_lectura_critica','punt_global']
              if c in df_raw.columns]

EXCLUDE_COLS = SCORE_COLS + [
    'estu_consecutivo',
    'periodo',
    'nivel_desempeno',
    'cole_cod_depto_ubicacion',

    # =========================
    # Variables adicionales
    # =========================
    'estu_tipodocumento',
    'cole_cod_mcpio_ubicacion',
    'cole_cod_departamento_unicacion',
    'cole_codigo_icfes',
    'cole_nombre_establecimiento',
    'cole_nombre_sede',
    'estu_cod_depto_presentacion',
    'estu_cod_mcpio_presentacion',
    'estu_cod_reside_mcpio',
    'estu_fechanacimiento',
    'estu_mcpio_presentacion',
    'estu_mcpio_reside',
    'estu_pais_reside',
    'desemp_ingles',
    'cole_mcpio_ubicacion',
    'cole_codigo_icfes',
    'cole_cod_dane_sede',
    'cole_cod_dane_establecimiento',
    'estu_cod_mcpio_presentacion'
]


TARGET       = 'nivel_desempeno'

# Excluir variables de alta cardinalidad (>200 categorías → problemas de memoria/encoding)
alta_card = []
for col in df.columns:
    if col not in EXCLUDE_COLS and df[col].dtype == object:
        if df[col].nunique() > 200:
            alta_card.append(col)
            EXCLUDE_COLS.append(col)

if alta_card:
    print(f'⚠️  Excluidas por alta cardinalidad (>{200} cat.): {alta_card}')

FEATURES     = [c for c in df.columns if c not in EXCLUDE_COLS]
NUM_FEATURES = df[FEATURES].select_dtypes(include='number').columns.tolist()
CAT_FEATURES = df[FEATURES].select_dtypes(include=['object','category']).columns.tolist()

print(f'\nTotal features: {len(FEATURES)}')
print(f'  → Numéricas  : {len(NUM_FEATURES)} → {NUM_FEATURES}')
print(f'  → Categóricas: {len(CAT_FEATURES)} → {CAT_FEATURES}')


# ── Eliminar duplicados (estu_consecutivo) ────────────────────────────────────
n_antes = len(df)
df = df[~df.duplicated(subset=['estu_consecutivo'], keep='first')].reset_index(drop=True)
print(f'Registros eliminados por duplicado: {n_antes - len(df):,}')

# ── Eliminar filas sin nivel_desempeno (sin punt_global válido) ────────────────
df = df.dropna(subset=['nivel_desempeno']).reset_index(drop=True)
print(f'Registros con target válido: {len(df):,}')

# ── Codificación numérica del target ──────────────────────────────────────────
label2idx = {l: i for i, l in enumerate(LABELS)}
df['target'] = df['nivel_desempeno'].map(label2idx)

print('\nCodificación del target:')
for l, i in label2idx.items():
    print(f'  {i} → {l}')

# ── Subsets por experimento ───────────────────────────────────────────────────
X_all = df[FEATURES].copy()
y_all = df['target'].copy()

# Experimento 1: solo filas completamente limpias
mask_clean = X_all.notna().all(axis=1)
X_exp1, y_exp1 = X_all[mask_clean].reset_index(drop=True), y_all[mask_clean].reset_index(drop=True)

# Experimento 2: dataset completo (con nulos — se imputará en el pipeline)
X_exp2, y_exp2 = X_all.copy(), y_all.copy()

print(f'Exp 1 (Eliminación): {len(X_exp1):,} registros ({len(X_exp1)/len(X_all)*100:.1f}%)')
print(f'Exp 2 (Imputación):  {len(X_exp2):,} registros ({len(X_exp2)/len(X_all)*100:.1f}%)')


# ── División Train / Test estratificada (80/20) ────────────────────────────────
RANDOM_STATE = 42

X_tr1, X_te1, y_tr1, y_te1 = train_test_split(
    X_exp1, y_exp1, test_size=0.20, random_state=RANDOM_STATE, stratify=y_exp1
)
X_tr2, X_te2, y_tr2, y_te2 = train_test_split(
    X_exp2, y_exp2, test_size=0.20, random_state=RANDOM_STATE, stratify=y_exp2
)

print('División Train / Test (80/20, estratificada):')
print(f'  Exp 1 → Train: {len(X_tr1):,}  |  Test: {len(X_te1):,}')
print(f'  Exp 2 → Train: {len(X_tr2):,}  |  Test: {len(X_te2):,}')


# Experimento 1: sin imputación (datos ya limpios)
proc_e1 = ColumnTransformer([
    ('num', StandardScaler(), NUM_FEATURES),
    ('cat', OneHotEncoder(handle_unknown='ignore'), CAT_FEATURES)
], remainder='drop')

# Experimento 2: con imputación antes de escalar/codificar
proc_e2 = ColumnTransformer([
    ('num', Pipeline([
        ('imp', SimpleImputer(strategy='median')),
        ('sc',  StandardScaler())
    ]), NUM_FEATURES),

    ('cat', Pipeline([
        ('imp', SimpleImputer(strategy='most_frequent')),
        ('enc', OneHotEncoder(handle_unknown='ignore'))
    ]), CAT_FEATURES)

], remainder='drop')

print('✅ Preprocesadores definidos.')
print('  Exp 1: StandardScaler + OneHotEncoder (sin imputación)')
print('  Exp 2: SimpleImputer(median/moda) + StandardScaler + OneHotEncoder')
# Out:
# ✅ Variable objetivo creada: nivel_desempeno
#   Clase  Conteo  % Total
# 0  Bajo  565188  52.0500
# 1  Alto  520749  47.9500
# Total features: 26
#   → Numéricas  : 0 → []
#   → Categóricas: 26 → ['cole_area_ubicacion', 'cole_calendario', 'cole_caracter', 'cole_depto_ubicacion', 'cole_genero', 'cole_jornada', 'cole_naturaleza', 'cole_sede_principal', 'estu_cod_reside_depto', 'estu_depto_presentacion', 'estu_depto_reside', 'estu_estadoinvestigacion', 'estu_estudiante', 'estu_genero', 'estu_nacionalidad', 'estu_privado_libertad', 'fami_cuartoshogar', 'fami_educacionmadre', 'fami_educacionpadre', 'fami_estratovivienda', 'fami_personashogar', 'fami_tieneautomovil', 'fami_tienecomputador', 'fami_tieneinternet', 'fami_tienelavadora', 'cole_bilingue']
# Registros eliminados por duplicado: 533,096
# Registros con target válido: 552,841
#
# Codificación del target:
#   0 → Bajo
#   1 → Alto
# Exp 1 (Eliminación): 406,448 registros (73.5%)
# Exp 2 (Imputación):  552,841 registros (100.0%)
# División Train / Test (80/20, estratificada):
#   Exp 1 → Train: 325,158  |  Test: 81,290
#   Exp 2 → Train: 442,272  |  Test: 110,569
# ✅ Preprocesadores definidos.
#   Exp 1: StandardScaler + OneHotEncoder (sin imputación)
#   Exp 2: SimpleImputer(median/moda) + StandardScaler + OneHotEncoder

# %% [markdown]
# # Experimentación elminacion 2 tags

# %%
from sklearn.pipeline import Pipeline
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import GridSearchCV, StratifiedKFold

# ── Pipeline ─────────────────────────────────────────────
pipe_lr = Pipeline([
    ('prep', proc_e1),
    ('clf', LogisticRegression(
        max_iter=3000,
        random_state=RANDOM_STATE,
        multi_class='auto'
    ))
])

# ── Grid ─────────────────────────────────────────────────
param_grid = {
    'clf__C': [0.01, 0.1, 1, 10, 100],
    'clf__class_weight': [None, 'balanced'],
    'clf__solver': ['lbfgs', 'newton-cg']
}

# ── CV ───────────────────────────────────────────────────
cv = StratifiedKFold(
    n_splits=5,
    shuffle=True,
    random_state=RANDOM_STATE
)

# ── Grid Search ──────────────────────────────────────────
grid_lr = GridSearchCV(
    estimator=pipe_lr,
    param_grid=param_grid,
    scoring='f1_macro',
    cv=cv,
    n_jobs=4,
    verbose=2,
    return_train_score=True
)

grid_lr.fit(X_tr1, y_tr1)

print("\nMejores parámetros:")
print(grid_lr.best_params_)

print("\nMejor F1 Macro CV:")
print(grid_lr.best_score_)
# Out:
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
#
# Mejores parámetros:
# {'clf__C': 100, 'clf__class_weight': 'balanced', 'clf__solver': 'lbfgs'}
#
# Mejor F1 Macro CV:
# 0.6863044711744914

# %%
best_lr = grid_lr.best_estimator_

yp_lr = best_lr.predict(X_te1)
ypr_lr = best_lr.predict_proba(X_te1)

met_lr = evaluar(
    'LR GridSearch',
    y_te1,
    yp_lr,
    ypr_lr
)
# Out:
# ══════════════════════════════════════════════════════════
#   LR GridSearch
# ══════════════════════════════════════════════════════════
#   Accuracy            : 0.6921
#   F1-score (macro)    : 0.6919
#   F1-score (weighted) : 0.6921
#   Precision (macro)   : 0.6919
#   Recall (macro)      : 0.6919
#   ROC-AUC             : 0.7641
#
# 📋 Classification Report:
#
#               precision    recall  f1-score   support
#
#            0       0.68      0.69      0.68     39640
#            1       0.70      0.70      0.70     41650
#
#     accuracy                           0.69     81290
#    macro avg       0.69      0.69      0.69     81290
# weighted avg       0.69      0.69      0.69     81290
#
#
# 📊 Matriz de Confusión (texto):
#
#         Pred_0  Pred_1
# Real_0   27178   12462
# Real_1   12570   29080

# %% [markdown]
# # Experimentación inptación 2 tags

# %%
from sklearn.pipeline import Pipeline
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import GridSearchCV, StratifiedKFold

# ── Pipeline ─────────────────────────────────────────────
pipe_lr = Pipeline([
    ('prep', proc_e2),
    ('clf', LogisticRegression(
        max_iter=3000,
        random_state=RANDOM_STATE,
        multi_class='auto'
    ))
])

# ── Grid ─────────────────────────────────────────────────
param_grid = {
    'clf__C': [0.01, 0.1, 1, 10, 100],
    'clf__class_weight': [None, 'balanced'],
    'clf__solver': ['lbfgs', 'newton-cg']
}

# ── CV ───────────────────────────────────────────────────
cv = StratifiedKFold(
    n_splits=5,
    shuffle=True,
    random_state=RANDOM_STATE
)

# ── Grid Search ──────────────────────────────────────────
grid_lr = GridSearchCV(
    estimator=pipe_lr,
    param_grid=param_grid,
    scoring='f1_macro',
    cv=cv,
    n_jobs=4,
    verbose=2,
    return_train_score=True
)

grid_lr.fit(X_tr1, y_tr1)

print("\nMejores parámetros:")
print(grid_lr.best_params_)

print("\nMejor F1 Macro CV:")
print(grid_lr.best_score_)
# Out:
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# [CV] END clf__C=0.01, clf__class_weight=None, clf__solver=lbfgs; total time=  12.1s
# [CV] END clf__C=0.01, clf__class_weight=None, clf__solver=newton-cg; total time=   8.5s
# [CV] END clf__C=0.01, clf__class_weight=balanced, clf__solver=lbfgs; total time=   6.4s
# [CV] END clf__C=0.01, clf__class_weight=balanced, clf__solver=newton-cg; total time=   8.7s
# [CV] END clf__C=0.01, clf__class_weight=balanced, clf__solver=newton-cg; total time=   8.1s
# [CV] END clf__C=0.1, clf__class_weight=None, clf__solver=lbfgs; total time=   8.6s
# [CV] END clf__C=0.1, clf__class_weight=None, clf__solver=newton-cg; total time=   7.0s
# [CV] END clf__C=0.1, clf__class_weight=balanced, clf__solver=lbfgs; total time=   9.9s
# [CV] END clf__C=0.1, clf__class_weight=balanced, clf__solver=newton-cg; total time=   7.5s
# [CV] END clf__C=0.1, clf__class_weight=balanced, clf__solver=newton-cg; total time=   7.3s
# [CV] END clf__C=1, clf__class_weight=None, clf__solver=lbfgs; total time=  10.8s
# [CV] END clf__C=1, clf__class_weight=None, clf__solver=newton-cg; total time=  17.5s
# [CV] END clf__C=1, clf__class_weight=balanced, clf__solver=lbfgs; total time=  13.3s
# [CV] END clf__C=1, clf__class_weight=balanced, clf__solver=newton-cg; total time=  10.3s
# [CV] END clf__C=1, clf__class_weight=balanced, clf__solver=newton-cg; total time=   9.4s
# [CV] END clf__C=10, clf__class_weight=None, clf__solver=lbfgs; total time=  12.4s
# [CV] END clf__C=10, clf__class_weight=None, clf__solver=newton-cg; total time=  17.7s
# [CV] END clf__C=10, clf__class_weight=balanced, clf__solver=lbfgs; total time=  11.9s
# [CV] END clf__C=10, clf__class_weight=balanced, clf__solver=lbfgs; total time=  17.4s
# [CV] END clf__C=10, clf__class_weight=balanced, clf__solver=newton-cg; total time=  19.6s
# [CV] END clf__C=100, clf__class_weight=None, clf__solver=lbfgs; total time=  10.2s
# [CV] END clf__C=100, clf__class_weight=None, clf__solver=lbfgs; total time=   9.5s
# [CV] END clf__C=100, clf__class_weight=None, clf__solver=newton-cg; total time=  17.1s
# [CV] END clf__C=100, clf__class_weight=balanced, clf__solver=lbfgs; total time=  16.7s
# [CV] END clf__C=100, clf__class_weight=balanced, clf__solver=newton-cg; total time=  17.8s
# [CV] END clf__C=100, clf__class_weight=balanced, clf__solver=newton-cg; total time=  17.2s
# [CV] END clf__C=0.01, clf__class_weight=None, clf__solver=lbfgs; total time=   6.8s
# [CV] END clf__C=0.01, clf__class_weight=None, clf__solver=newton-cg; total time=   8.7s
# [CV] END clf__C=0.01, clf__class_weight=balanced, clf__solver=lbfgs; total time=   6.5s
# [CV] END clf__C=0.01, clf__class_weight=balanced, clf__solver=newton-cg; total time=   9.1s
# [CV] END clf__C=0.01, clf__class_weight=balanced, clf__solver=newton-cg; total time=   8.9s
# [CV] END clf__C=0.1, clf__class_weight=None, clf__solver=lbfgs; total time=   8.7s
# [CV] END clf__C=0.1, clf__class_weight=None, clf__solver=newton-cg; total time=   7.6s
# [CV] END clf__C=0.1, clf__class_weight=balanced, clf__solver=lbfgs; total time=  10.3s
# [CV] END clf__C=0.1, clf__class_weight=balanced, clf__solver=newton-cg; total time=   8.3s
# [CV] END clf__C=0.1, clf__class_weight=balanced, clf__solver=newton-cg; total time=   7.0s
# [CV] END clf__C=1, clf__class_weight=None, clf__solver=lbfgs; total time=  11.6s
# [CV] END clf__C=1, clf__class_weight=None, clf__solver=newton-cg; total time=  17.9s
# [CV] END clf__C=1, clf__class_weight=balanced, clf__solver=lbfgs; total time=  13.3s
# [CV] END clf__C=1, clf__class_weight=balanced, clf__solver=lbfgs; total time=  13.7s
# [CV] END clf__C=1, clf__class_weight=balanced, clf__solver=newton-cg; total time=  17.8s
# [CV] END clf__C=10, clf__class_weight=None, clf__solver=lbfgs; total time=  11.6s
# [CV] END clf__C=10, clf__class_weight=None, clf__solver=newton-cg; total time=  21.0s
# [CV] END clf__C=10, clf__class_weight=balanced, clf__solver=lbfgs; total time=  16.9s
# [CV] END clf__C=10, clf__class_weight=balanced, clf__solver=newton-cg; total time=  20.6s
# [CV] END clf__C=100, clf__class_weight=None, clf__solver=lbfgs; total time=  10.0s
# [CV] END clf__C=100, clf__class_weight=None, clf__solver=lbfgs; total time=   8.5s
# [CV] END clf__C=100, clf__class_weight=None, clf__solver=newton-cg; total time=  20.0s
# [CV] END clf__C=100, clf__class_weight=balanced, clf__solver=lbfgs; total time=  12.7s
# [CV] END clf__C=100, clf__class_weight=balanced, clf__solver=lbfgs; total time=  15.8s
# [CV] END clf__C=100, clf__class_weight=balanced, clf__solver=newton-cg; total time=  18.2s
# [CV] END clf__C=0.01, clf__class_weight=None, clf__solver=lbfgs; total time=   2.5s
# [CV] END clf__C=0.01, clf__class_weight=None, clf__solver=newton-cg; total time=   2.2s
# [CV] END clf__C=0.01, clf__class_weight=None, clf__solver=newton-cg; total time=   2.3s
# [CV] END clf__C=0.01, clf__class_weight=balanced, clf__solver=lbfgs; total time=   2.2s
# [CV] END clf__C=0.01, clf__class_weight=balanced, clf__solver=newton-cg; total time=   2.2s
# [CV] END clf__C=0.1, clf__class_weight=None, clf__solver=lbfgs; total time=   3.1s
# [CV] END clf__C=0.1, clf__class_weight=None, clf__solver=newton-cg; total time=   3.7s
# [CV] END clf__C=0.1, clf__class_weight=None, clf__solver=newton-cg; total time=   3.6s
# [CV] END clf__C=0.1, clf__class_weight=balanced, clf__solver=lbfgs; total time=   2.4s
# [CV] END clf__C=0.1, clf__class_weight=balanced, clf__solver=newton-cg; total time=   4.4s
# [CV] END clf__C=1, clf__class_weight=None, clf__solver=lbfgs; total time=   4.2s
# [CV] END clf__C=1, clf__class_weight=None, clf__solver=newton-cg; total time=   5.7s
# [CV] END clf__C=1, clf__class_weight=balanced, clf__solver=lbfgs; total time=   3.9s
# [CV] END clf__C=1, clf__class_weight=balanced, clf__solver=lbfgs; total time=   2.8s
# [CV] END clf__C=1, clf__class_weight=balanced, clf__solver=newton-cg; total time=   6.3s
# [CV] END clf__C=10, clf__class_weight=None, clf__solver=lbfgs; total time=   3.8s
# [CV] END clf__C=10, clf__class_weight=None, clf__solver=newton-cg; total time=   7.1s
# [CV] END clf__C=10, clf__class_weight=balanced, clf__solver=lbfgs; total time=   3.8s
# [CV] END clf__C=10, clf__class_weight=balanced, clf__solver=lbfgs; total time=   3.8s
# [CV] END clf__C=10, clf__class_weight=balanced, clf__solver=newton-cg; total time=   6.9s
# [CV] END clf__C=100, clf__class_weight=None, clf__solver=lbfgs; total time=   5.0s
# [CV] END clf__C=100, clf__class_weight=None, clf__solver=newton-cg; total time=   7.2s
# [CV] END clf__C=100, clf__class_weight=balanced, clf__solver=lbfgs; total time=   4.0s
# [CV] END clf__C=100, clf__class_weight=balanced, clf__solver=lbfgs; total time=   2.6s
# [CV] END clf__C=100, clf__class_weight=balanced, clf__solver=newton-cg; total time=   6.8s
# [CV] END clf__C=0.01, clf__class_weight=None, clf__solver=lbfgs; total time=   2.6s
# [CV] END clf__C=0.01, clf__class_weight=None, clf__solver=lbfgs; total time=   2.8s
# [CV] END clf__C=0.01, clf__class_weight=None, clf__solver=newton-cg; total time=   2.7s
# [CV] END clf__C=0.01, clf__class_weight=balanced, clf__solver=lbfgs; total time=   2.5s
# [CV] END clf__C=0.01, clf__class_weight=balanced, clf__solver=newton-cg; total time=   2.5s
# [CV] END clf__C=0.1, clf__class_weight=None, clf__solver=lbfgs; total time=   2.6s
# [CV] END clf__C=0.1, clf__class_weight=None, clf__solver=lbfgs; total time=   2.8s
# [CV] END clf__C=0.1, clf__class_weight=None, clf__solver=newton-cg; total time=   3.8s
# [CV] END clf__C=0.1, clf__class_weight=balanced, clf__solver=lbfgs; total time=   3.4s
# [CV] END clf__C=0.1, clf__class_weight=balanced, clf__solver=newton-cg; total time=   4.4s
# [CV] END clf__C=1, clf__class_weight=None, clf__solver=lbfgs; total time=   4.8s
# [CV] END clf__C=1, clf__class_weight=None, clf__solver=lbfgs; total time=   3.1s
# [CV] END clf__C=1, clf__class_weight=None, clf__solver=newton-cg; total time=   4.8s
# [CV] END clf__C=1, clf__class_weight=balanced, clf__solver=lbfgs; total time=   3.6s
# [CV] END clf__C=1, clf__class_weight=balanced, clf__solver=newton-cg; total time=   6.0s
# [CV] END clf__C=10, clf__class_weight=None, clf__solver=lbfgs; total time=   3.1s
# [CV] END clf__C=10, clf__class_weight=None, clf__solver=lbfgs; total time=   3.3s
# [CV] END clf__C=10, clf__class_weight=None, clf__solver=newton-cg; total time=   7.3s
# [CV] END clf__C=10, clf__class_weight=balanced, clf__solver=lbfgs; total time=   4.1s[CV] END clf__C=0.01, clf__class_weight=None, clf__solver=lbfgs; total time=   7.7s
# [CV] END clf__C=0.01, clf__class_weight=None, clf__solver=newton-cg; total time=   8.4s
# [CV] END clf__C=0.01, clf__class_weight=balanced, clf__solver=lbfgs; total time=   6.2s
# [CV] END clf__C=0.01, clf__class_weight=balanced, clf__solver=lbfgs; total time=   6.8s
# [CV] END clf__C=0.01, clf__class_weight=balanced, clf__solver=newton-cg; total time=   5.3s
# [CV] END clf__C=0.1, clf__class_weight=None, clf__solver=lbfgs; total time=  10.1s
# [CV] END clf__C=0.1, clf__class_weight=None, clf__solver=newton-cg; total time=   6.6s
# [CV] END clf__C=0.1, clf__class_weight=None, clf__solver=newton-cg; total time=   6.5s
# [CV] END clf__C=0.1, clf__class_weight=balanced, clf__solver=lbfgs; total time=  11.1s
# [CV] END clf__C=0.1, clf__class_weight=balanced, clf__solver=newton-cg; total time=   7.1s
# [CV] END clf__C=1, clf__class_weight=None, clf__solver=lbfgs; total time=  12.0s
# [CV] END clf__C=1, clf__class_weight=None, clf__solver=newton-cg; total time=  16.7s
# [CV] END clf__C=1, clf__class_weight=None, clf__solver=newton-cg; total time=  16.4s
# [CV] END clf__C=1, clf__class_weight=balanced, clf__solver=lbfgs; total time=  12.2s
# [CV] END clf__C=1, clf__class_weight=balanced, clf__solver=newton-cg; total time=  10.0s
# [CV] END clf__C=10, clf__class_weight=None, clf__solver=lbfgs; total time=   8.3s
# [CV] END clf__C=10, clf__class_weight=None, clf__solver=lbfgs; total time=   9.8s
# [CV] END clf__C=10, clf__class_weight=None, clf__solver=newton-cg; total time=  20.4s
# [CV] END clf__C=10, clf__class_weight=balanced, clf__solver=lbfgs; total time=  16.9s
# [CV] END clf__C=10, clf__class_weight=balanced, clf__solver=newton-cg; total time=  17.6s
# [CV] END clf__C=100, clf__class_weight=None, clf__solver=lbfgs; total time=   9.4s
# [CV] END clf__C=100, clf__class_weight=None, clf__solver=lbfgs; total time=   9.3s
# [CV] END clf__C=100, clf__class_weight=None, clf__solver=newton-cg; total time=  18.3s
# [CV] END clf__C=100, clf__class_weight=balanced, clf__solver=lbfgs; total time=  16.3s
# [CV] END clf__C=100, clf__class_weight=balanced, clf__solver=newton-cg; total time=  31.8s
# [CV] END clf__C=0.01, clf__class_weight=None, clf__solver=lbfgs; total time=   6.7s
# [CV] END clf__C=0.01, clf__class_weight=None, clf__solver=newton-cg; total time=   8.7s
# [CV] END clf__C=0.01, clf__class_weight=balanced, clf__solver=lbfgs; total time=   6.4s
# [CV] END clf__C=0.01, clf__class_weight=balanced, clf__solver=lbfgs; total time=   7.0s
# [CV] END clf__C=0.01, clf__class_weight=balanced, clf__solver=newton-cg; total time=   5.8s
# [CV] END clf__C=0.1, clf__class_weight=None, clf__solver=lbfgs; total time=  11.2s
# [CV] END clf__C=0.1, clf__class_weight=None, clf__solver=newton-cg; total time=   6.7s
# [CV] END clf__C=0.1, clf__class_weight=None, clf__solver=newton-cg; total time=   7.2s
# [CV] END clf__C=0.1, clf__class_weight=balanced, clf__solver=lbfgs; total time=  11.5s
# [CV] END clf__C=0.1, clf__class_weight=balanced, clf__solver=newton-cg; total time=   7.4s
# [CV] END clf__C=1, clf__class_weight=None, clf__solver=lbfgs; total time=  13.5s
# [CV] END clf__C=1, clf__class_weight=None, clf__solver=newton-cg; total time=  17.1s
# [CV] END clf__C=1, clf__class_weight=None, clf__solver=newton-cg; total time=  18.3s
# [CV] END clf__C=1, clf__class_weight=balanced, clf__solver=newton-cg; total time=  11.4s
# [CV] END clf__C=1, clf__class_weight=balanced, clf__solver=newton-cg; total time=  10.1s
# [CV] END clf__C=10, clf__class_weight=None, clf__solver=lbfgs; total time=  12.8s
# [CV] END clf__C=10, clf__class_weight=None, clf__solver=newton-cg; total time=  18.9s
# [CV] END clf__C=10, clf__class_weight=balanced, clf__solver=lbfgs; total time=  12.0s
# [CV] END clf__C=10, clf__class_weight=balanced, clf__solver=lbfgs; total time=  18.2s
# [CV] END clf__C=10, clf__class_weight=balanced, clf__solver=newton-cg; total time=  20.6s
# [CV] END clf__C=100, clf__class_weight=None, clf__solver=lbfgs; total time=  10.3s
# [CV] END clf__C=100, clf__class_weight=None, clf__solver=lbfgs; total time=  10.2s
# [CV] END clf__C=100, clf__class_weight=None, clf__solver=newton-cg; total time=  18.1s
# [CV] END clf__C=100, clf__class_weight=balanced, clf__solver=lbfgs; total time=  14.7s
# [CV] END clf__C=100, clf__class_weight=balanced, clf__solver=newton-cg; total time=  18.0s
# [CV] END clf__C=100, clf__class_weight=balanced, clf__solver=newton-cg; total time=  17.7s
# [CV] END clf__C=0.01, clf__class_weight=None, clf__solver=lbfgs; total time=   2.4s
# [CV] END clf__C=0.01, clf__class_weight=None, clf__solver=newton-cg; total time=   2.5s
# [CV] END clf__C=0.01, clf__class_weight=balanced, clf__solver=lbfgs; total time=   2.4s
# [CV] END clf__C=0.01, clf__class_weight=balanced, clf__solver=lbfgs; total time=   2.4s
# [CV] END clf__C=0.01, clf__class_weight=balanced, clf__solver=newton-cg; total time=   2.4s
# [CV] END clf__C=0.1, clf__class_weight=None, clf__solver=lbfgs; total time=   3.2s
# [CV] END clf__C=0.1, clf__class_weight=None, clf__solver=newton-cg; total time=   4.2s
# [CV] END clf__C=0.1, clf__class_weight=balanced, clf__solver=lbfgs; total time=   2.7s
# [CV] END clf__C=0.1, clf__class_weight=balanced, clf__solver=lbfgs; total time=   2.5s
# [CV] END clf__C=0.1, clf__class_weight=balanced, clf__solver=newton-cg; total time=   4.2s
# [CV] END clf__C=1, clf__class_weight=None, clf__solver=lbfgs; total time=   3.6s
# [CV] END clf__C=1, clf__class_weight=None, clf__solver=newton-cg; total time=   5.6s
# [CV] END clf__C=1, clf__class_weight=None, clf__solver=newton-cg; total time=   4.6s
# [CV] END clf__C=1, clf__class_weight=balanced, clf__solver=lbfgs; total time=   2.5s
# [CV] END clf__C=1, clf__class_weight=balanced, clf__solver=newton-cg; total time=   5.8s
# [CV] END clf__C=10, clf__class_weight=None, clf__solver=lbfgs; total time=   3.7s
# [CV] END clf__C=10, clf__class_weight=None, clf__solver=newton-cg; total time=   7.0s
# [CV] END clf__C=10, clf__class_weight=None, clf__solver=newton-cg; total time=   5.7s
# [CV] END clf__C=10, clf__class_weight=balanced, clf__solver=newton-cg; total time=   6.3s
# [CV] END clf__C=10, clf__class_weight=balanced, clf__solver=newton-cg; total time=   6.7s
# [CV] END clf__C=100, clf__class_weight=None, clf__solver=lbfgs; total time=   3.3s
# [CV] END clf__C=100, clf__class_weight=None, clf__solver=newton-cg; total time=   7.3s
# [CV] END clf__C=100, clf__class_weight=balanced, clf__solver=lbfgs; total time=   3.6s
# [CV] END clf__C=100, clf__class_weight=balanced, clf__solver=newton-cg; total time=   6.7s
# [CV] END clf__C=0.01, clf__class_weight=None, clf__solver=lbfgs; total time=   3.1s
# [CV] END clf__C=0.01, clf__class_weight=None, clf__solver=newton-cg; total time=   2.7s
# [CV] END clf__C=0.01, clf__class_weight=None, clf__solver=newton-cg; total time=   2.6s
# [CV] END clf__C=0.01, clf__class_weight=balanced, clf__solver=lbfgs; total time=   2.7s
# [CV] END clf__C=0.01, clf__class_weight=balanced, clf__solver=newton-cg; total time=   2.6s
# [CV] END clf__C=0.1, clf__class_weight=None, clf__solver=lbfgs; total time=   3.2s
# [CV] END clf__C=0.1, clf__class_weight=None, clf__solver=newton-cg; total time=   4.1s
# [CV] END clf__C=0.1, clf__class_weight=None, clf__solver=newton-cg; total time=   3.9s
# [CV] END clf__C=0.1, clf__class_weight=balanced, clf__solver=lbfgs; total time=   2.8s
# [CV] END clf__C=0.1, clf__class_weight=balanced, clf__solver=newton-cg; total time=   4.6s
# [CV] END clf__C=1, clf__class_weight=None, clf__solver=lbfgs; total time=   4.8s
# [CV] END clf__C=1, clf__class_weight=None, clf__solver=newton-cg; total time=   5.8s
# [CV] END clf__C=1, clf__class_weight=None, clf__solver=newton-cg; total time=   5.1s
# [CV] END clf__C=1, clf__class_weight=balanced, clf__solver=lbfgs; total time=   3.2s
# [CV] END clf__C=1, clf__class_weight=balanced, clf__solver=newton-cg; total time=   6.7s
# [CV] END clf__C=10, clf__class_weight=None, clf__solver=lbfgs; total time=   4.3s
# [CV] END clf__C=10, clf__class_weight=None, clf__solver=newton-cg; total time=   7.6s
# [CV] END clf__C=10, clf__class_weight=balanced, clf__solver=lbfgs; total time=   4.2s
# [CV] END clf__C=10, clf__class_weight=balanced, clf__solver=lbfgs; total time=   4.2s
# [CV] END clf__C=10, clf__class_weight=balanced, clf__solver=newton-cg; total time=   7.7s[CV] END clf__C=0.01, clf__class_weight=None, clf__solver=lbfgs; total time=   9.7s
# [CV] END clf__C=0.01, clf__class_weight=None, clf__solver=newton-cg; total time=   7.4s
# [CV] END clf__C=0.01, clf__class_weight=None, clf__solver=newton-cg; total time=   7.6s
# [CV] END clf__C=0.01, clf__class_weight=balanced, clf__solver=lbfgs; total time=   6.1s
# [CV] END clf__C=0.01, clf__class_weight=balanced, clf__solver=newton-cg; total time=   5.2s
# [CV] END clf__C=0.1, clf__class_weight=None, clf__solver=lbfgs; total time=   7.3s
# [CV] END clf__C=0.1, clf__class_weight=None, clf__solver=lbfgs; total time=   7.3s
# [CV] END clf__C=0.1, clf__class_weight=None, clf__solver=newton-cg; total time=   6.7s
# [CV] END clf__C=0.1, clf__class_weight=balanced, clf__solver=lbfgs; total time=  11.6s
# [CV] END clf__C=0.1, clf__class_weight=balanced, clf__solver=newton-cg; total time=   6.1s
# [CV] END clf__C=1, clf__class_weight=None, clf__solver=lbfgs; total time=  11.8s
# [CV] END clf__C=1, clf__class_weight=None, clf__solver=lbfgs; total time=   8.0s
# [CV] END clf__C=1, clf__class_weight=None, clf__solver=newton-cg; total time=  16.6s
# [CV] END clf__C=1, clf__class_weight=balanced, clf__solver=lbfgs; total time=  13.6s
# [CV] END clf__C=1, clf__class_weight=balanced, clf__solver=newton-cg; total time=  18.3s
# [CV] END clf__C=10, clf__class_weight=None, clf__solver=lbfgs; total time=  11.5s
# [CV] END clf__C=10, clf__class_weight=None, clf__solver=newton-cg; total time=  15.9s
# [CV] END clf__C=10, clf__class_weight=None, clf__solver=newton-cg; total time=  18.2s
# [CV] END clf__C=10, clf__class_weight=balanced, clf__solver=lbfgs; total time=  19.9s
# [CV] END clf__C=10, clf__class_weight=balanced, clf__solver=newton-cg; total time=  26.2s
# [CV] END clf__C=100, clf__class_weight=None, clf__solver=newton-cg; total time=  15.8s
# [CV] END clf__C=100, clf__class_weight=None, clf__solver=newton-cg; total time=  17.5s
# [CV] END clf__C=100, clf__class_weight=balanced, clf__solver=lbfgs; total time=  12.8s
# [CV] END clf__C=100, clf__class_weight=balanced, clf__solver=newton-cg; total time=  21.5s
# [CV] END clf__C=0.01, clf__class_weight=None, clf__solver=lbfgs; total time=   4.8s
# [CV] END clf__C=0.01, clf__class_weight=None, clf__solver=lbfgs; total time=   6.3s
# [CV] END clf__C=0.01, clf__class_weight=None, clf__solver=newton-cg; total time=   7.9s
# [CV] END clf__C=0.01, clf__class_weight=balanced, clf__solver=lbfgs; total time=   7.5s
# [CV] END clf__C=0.01, clf__class_weight=balanced, clf__solver=newton-cg; total time=   6.4s
# [CV] END clf__C=0.1, clf__class_weight=None, clf__solver=lbfgs; total time=   8.2s
# [CV] END clf__C=0.1, clf__class_weight=None, clf__solver=lbfgs; total time=   7.3s
# [CV] END clf__C=0.1, clf__class_weight=None, clf__solver=newton-cg; total time=   7.3s
# [CV] END clf__C=0.1, clf__class_weight=balanced, clf__solver=lbfgs; total time=  13.1s
# [CV] END clf__C=0.1, clf__class_weight=balanced, clf__solver=newton-cg; total time=   6.7s
# [CV] END clf__C=1, clf__class_weight=None, clf__solver=lbfgs; total time=  12.8s
# [CV] END clf__C=1, clf__class_weight=None, clf__solver=lbfgs; total time=   8.0s
# [CV] END clf__C=1, clf__class_weight=None, clf__solver=newton-cg; total time=  17.6s
# [CV] END clf__C=1, clf__class_weight=balanced, clf__solver=lbfgs; total time=  14.3s
# [CV] END clf__C=1, clf__class_weight=balanced, clf__solver=newton-cg; total time=  19.3s
# [CV] END clf__C=10, clf__class_weight=None, clf__solver=lbfgs; total time=  11.5s
# [CV] END clf__C=10, clf__class_weight=None, clf__solver=lbfgs; total time=  10.9s
# [CV] END clf__C=10, clf__class_weight=None, clf__solver=newton-cg; total time=  20.6s
# [CV] END clf__C=10, clf__class_weight=balanced, clf__solver=lbfgs; total time=  17.2s
# [CV] END clf__C=10, clf__class_weight=balanced, clf__solver=newton-cg; total time=  18.1s
# [CV] END clf__C=10, clf__class_weight=balanced, clf__solver=newton-cg; total time=  12.2s
# [CV] END clf__C=100, clf__class_weight=None, clf__solver=lbfgs; total time=   9.5s
# [CV] END clf__C=100, clf__class_weight=None, clf__solver=newton-cg; total time=  19.1s
# [CV] END clf__C=100, clf__class_weight=balanced, clf__solver=lbfgs; total time=  16.8s
# [CV] END clf__C=100, clf__class_weight=balanced, clf__solver=newton-cg; total time=  29.9s
# [CV] END clf__C=0.01, clf__class_weight=None, clf__solver=lbfgs; total time=   2.2s
# [CV] END clf__C=0.01, clf__class_weight=None, clf__solver=lbfgs; total time=   2.3s
# [CV] END clf__C=0.01, clf__class_weight=None, clf__solver=newton-cg; total time=   2.3s
# [CV] END clf__C=0.01, clf__class_weight=balanced, clf__solver=lbfgs; total time=   1.9s
# [CV] END clf__C=0.01, clf__class_weight=balanced, clf__solver=newton-cg; total time=   2.1s
# [CV] END clf__C=0.1, clf__class_weight=None, clf__solver=lbfgs; total time=   2.3s
# [CV] END clf__C=0.1, clf__class_weight=None, clf__solver=lbfgs; total time=   2.5s
# [CV] END clf__C=0.1, clf__class_weight=None, clf__solver=newton-cg; total time=   3.8s
# [CV] END clf__C=0.1, clf__class_weight=balanced, clf__solver=lbfgs; total time=   3.0s
# [CV] END clf__C=0.1, clf__class_weight=balanced, clf__solver=newton-cg; total time=   3.5s
# [CV] END clf__C=1, clf__class_weight=None, clf__solver=lbfgs; total time=   4.8s
# [CV] END clf__C=1, clf__class_weight=None, clf__solver=lbfgs; total time=   2.5s
# [CV] END clf__C=1, clf__class_weight=None, clf__solver=newton-cg; total time=   5.4s
# [CV] END clf__C=1, clf__class_weight=balanced, clf__solver=lbfgs; total time=   3.5s
# [CV] END clf__C=1, clf__class_weight=balanced, clf__solver=newton-cg; total time=   5.6s
# [CV] END clf__C=10, clf__class_weight=None, clf__solver=lbfgs; total time=   3.1s
# [CV] END clf__C=10, clf__class_weight=None, clf__solver=lbfgs; total time=   2.8s
# [CV] END clf__C=10, clf__class_weight=None, clf__solver=newton-cg; total time=   7.3s
# [CV] END clf__C=10, clf__class_weight=balanced, clf__solver=lbfgs; total time=   6.4s
# [CV] END clf__C=10, clf__class_weight=balanced, clf__solver=newton-cg; total time=   7.1s
# [CV] END clf__C=100, clf__class_weight=None, clf__solver=lbfgs; total time=   2.5s
# [CV] END clf__C=100, clf__class_weight=None, clf__solver=lbfgs; total time=   3.6s
# [CV] END clf__C=100, clf__class_weight=None, clf__solver=newton-cg; total time=   7.5s
# [CV] END clf__C=100, clf__class_weight=balanced, clf__solver=lbfgs; total time=   3.1s
# [CV] END clf__C=100, clf__class_weight=balanced, clf__solver=lbfgs; total time=   3.3s
# [CV] END clf__C=100, clf__class_weight=balanced, clf__solver=newton-cg; total time=   6.2s
# [CV] END clf__C=0.01, clf__class_weight=None, clf__solver=lbfgs; total time=   2.8s
# [CV] END clf__C=0.01, clf__class_weight=None, clf__solver=newton-cg; total time=   2.8s
# [CV] END clf__C=0.01, clf__class_weight=balanced, clf__solver=lbfgs; total time=   2.9s
# [CV] END clf__C=0.01, clf__class_weight=balanced, clf__solver=newton-cg; total time=   2.6s
# [CV] END clf__C=0.01, clf__class_weight=balanced, clf__solver=newton-cg; total time=   2.7s
# [CV] END clf__C=0.1, clf__class_weight=None, clf__solver=lbfgs; total time=   4.0s
# [CV] END clf__C=0.1, clf__class_weight=None, clf__solver=newton-cg; total time=   4.3s
# [CV] END clf__C=0.1, clf__class_weight=balanced, clf__solver=lbfgs; total time=   3.4s
# [CV] END clf__C=0.1, clf__class_weight=balanced, clf__solver=newton-cg; total time=   3.9s
# [CV] END clf__C=0.1, clf__class_weight=balanced, clf__solver=newton-cg; total time=   4.2s
# [CV] END clf__C=1, clf__class_weight=None, clf__solver=lbfgs; total time=   3.6s
# [CV] END clf__C=1, clf__class_weight=None, clf__solver=newton-cg; total time=   6.1s
# [CV] END clf__C=1, clf__class_weight=balanced, clf__solver=lbfgs; total time=   4.6s
# [CV] END clf__C=1, clf__class_weight=balanced, clf__solver=newton-cg; total time=   5.1s
# [CV] END clf__C=1, clf__class_weight=balanced, clf__solver=newton-cg; total time=   5.2s
# [CV] END clf__C=10, clf__class_weight=None, clf__solver=lbfgs; total time=   3.3s
# [CV] END clf__C=10, clf__class_weight=None, clf__solver=newton-cg; total time=   7.8s
# [CV] END clf__C=10, clf__class_weight=balanced, clf__solver=lbfgs; total time=   6.3s
# [CV] END clf__C=10, clf__class_weight=balanced, clf__solver=newton-cg; total time=   7.6s
# [CV] END clf__C=100, clf__class_weight=None, clf__solver=lbfgs; total time=   3.4s[CV] END clf__C=0.01, clf__class_weight=None, clf__solver=lbfgs; total time=  16.2s
# [CV] END clf__C=0.01, clf__class_weight=None, clf__solver=lbfgs; total time=   6.4s
# [CV] END clf__C=0.01, clf__class_weight=None, clf__solver=newton-cg; total time=   8.8s
# [CV] END clf__C=0.01, clf__class_weight=balanced, clf__solver=lbfgs; total time=   5.8s
# [CV] END clf__C=0.01, clf__class_weight=balanced, clf__solver=newton-cg; total time=   5.7s
# [CV] END clf__C=0.1, clf__class_weight=None, clf__solver=lbfgs; total time=  11.2s
# [CV] END clf__C=0.1, clf__class_weight=None, clf__solver=newton-cg; total time=   7.3s
# [CV] END clf__C=0.1, clf__class_weight=balanced, clf__solver=lbfgs; total time=  10.1s
# [CV] END clf__C=0.1, clf__class_weight=balanced, clf__solver=lbfgs; total time=  10.1s
# [CV] END clf__C=0.1, clf__class_weight=balanced, clf__solver=newton-cg; total time=   6.0s
# [CV] END clf__C=1, clf__class_weight=None, clf__solver=lbfgs; total time=  11.0s
# [CV] END clf__C=1, clf__class_weight=None, clf__solver=newton-cg; total time=  17.4s
# [CV] END clf__C=1, clf__class_weight=balanced, clf__solver=lbfgs; total time=  13.1s
# [CV] END clf__C=1, clf__class_weight=balanced, clf__solver=lbfgs; total time=  12.6s
# [CV] END clf__C=1, clf__class_weight=balanced, clf__solver=newton-cg; total time=  17.5s
# [CV] END clf__C=10, clf__class_weight=None, clf__solver=lbfgs; total time=   9.3s
# [CV] END clf__C=10, clf__class_weight=None, clf__solver=newton-cg; total time=  20.2s
# [CV] END clf__C=10, clf__class_weight=balanced, clf__solver=lbfgs; total time=  15.2s
# [CV] END clf__C=10, clf__class_weight=balanced, clf__solver=newton-cg; total time=  20.5s
# [CV] END clf__C=10, clf__class_weight=balanced, clf__solver=newton-cg; total time=  11.4s
# [CV] END clf__C=100, clf__class_weight=None, clf__solver=lbfgs; total time=   8.5s
# [CV] END clf__C=100, clf__class_weight=None, clf__solver=newton-cg; total time=  18.8s
# [CV] END clf__C=100, clf__class_weight=balanced, clf__solver=lbfgs; total time=  13.5s
# [CV] END clf__C=100, clf__class_weight=balanced, clf__solver=lbfgs; total time=  15.4s
# [CV] END clf__C=100, clf__class_weight=balanced, clf__solver=newton-cg; total time=  19.1s
# [CV] END clf__C=0.01, clf__class_weight=None, clf__solver=lbfgs; total time=   6.4s
# [CV] END clf__C=0.01, clf__class_weight=None, clf__solver=newton-cg; total time=   7.7s
# [CV] END clf__C=0.01, clf__class_weight=None, clf__solver=newton-cg; total time=   7.6s
# [CV] END clf__C=0.01, clf__class_weight=balanced, clf__solver=lbfgs; total time=   6.7s
# [CV] END clf__C=0.01, clf__class_weight=balanced, clf__solver=newton-cg; total time=   6.0s
# [CV] END clf__C=0.1, clf__class_weight=None, clf__solver=lbfgs; total time=  12.3s
# [CV] END clf__C=0.1, clf__class_weight=None, clf__solver=newton-cg; total time=   7.7s
# [CV] END clf__C=0.1, clf__class_weight=balanced, clf__solver=lbfgs; total time=  10.3s
# [CV] END clf__C=0.1, clf__class_weight=balanced, clf__solver=lbfgs; total time=  10.9s
# [CV] END clf__C=0.1, clf__class_weight=balanced, clf__solver=newton-cg; total time=   8.1s
# [CV] END clf__C=1, clf__class_weight=None, clf__solver=lbfgs; total time=  11.7s
# [CV] END clf__C=1, clf__class_weight=None, clf__solver=newton-cg; total time=  18.0s
# [CV] END clf__C=1, clf__class_weight=balanced, clf__solver=lbfgs; total time=  14.3s
# [CV] END clf__C=1, clf__class_weight=balanced, clf__solver=lbfgs; total time=  13.8s
# [CV] END clf__C=1, clf__class_weight=balanced, clf__solver=newton-cg; total time=  10.3s
# [CV] END clf__C=10, clf__class_weight=None, clf__solver=lbfgs; total time=   9.9s
# [CV] END clf__C=10, clf__class_weight=None, clf__solver=newton-cg; total time=  16.9s
# [CV] END clf__C=10, clf__class_weight=None, clf__solver=newton-cg; total time=  18.9s
# [CV] END clf__C=10, clf__class_weight=balanced, clf__solver=lbfgs; total time=  19.2s
# [CV] END clf__C=10, clf__class_weight=balanced, clf__solver=newton-cg; total time=  27.1s
# [CV] END clf__C=100, clf__class_weight=None, clf__solver=newton-cg; total time=  16.9s
# [CV] END clf__C=100, clf__class_weight=None, clf__solver=newton-cg; total time=  18.8s
# [CV] END clf__C=100, clf__class_weight=balanced, clf__solver=lbfgs; total time=  14.9s
# [CV] END clf__C=100, clf__class_weight=balanced, clf__solver=newton-cg; total time=  20.2s
# [CV] END clf__C=0.01, clf__class_weight=None, clf__solver=lbfgs; total time=   2.8s
# [CV] END clf__C=0.01, clf__class_weight=None, clf__solver=newton-cg; total time=   2.4s
# [CV] END clf__C=0.01, clf__class_weight=balanced, clf__solver=lbfgs; total time=   2.2s
# [CV] END clf__C=0.01, clf__class_weight=balanced, clf__solver=newton-cg; total time=   2.1s
# [CV] END clf__C=0.01, clf__class_weight=balanced, clf__solver=newton-cg; total time=   2.3s
# [CV] END clf__C=0.1, clf__class_weight=None, clf__solver=lbfgs; total time=   3.0s
# [CV] END clf__C=0.1, clf__class_weight=None, clf__solver=newton-cg; total time=   4.3s
# [CV] END clf__C=0.1, clf__class_weight=balanced, clf__solver=lbfgs; total time=   2.8s
# [CV] END clf__C=0.1, clf__class_weight=balanced, clf__solver=newton-cg; total time=   3.7s
# [CV] END clf__C=0.1, clf__class_weight=balanced, clf__solver=newton-cg; total time=   3.9s
# [CV] END clf__C=1, clf__class_weight=None, clf__solver=lbfgs; total time=   3.6s
# [CV] END clf__C=1, clf__class_weight=None, clf__solver=newton-cg; total time=   5.8s
# [CV] END clf__C=1, clf__class_weight=balanced, clf__solver=lbfgs; total time=   3.9s
# [CV] END clf__C=1, clf__class_weight=balanced, clf__solver=newton-cg; total time=   5.1s
# [CV] END clf__C=1, clf__class_weight=balanced, clf__solver=newton-cg; total time=   4.7s
# [CV] END clf__C=10, clf__class_weight=None, clf__solver=lbfgs; total time=   3.0s
# [CV] END clf__C=10, clf__class_weight=None, clf__solver=newton-cg; total time=   7.1s
# [CV] END clf__C=10, clf__class_weight=balanced, clf__solver=lbfgs; total time=   3.1s
# [CV] END clf__C=10, clf__class_weight=balanced, clf__solver=lbfgs; total time=   2.6s
# [CV] END clf__C=10, clf__class_weight=balanced, clf__solver=newton-cg; total time=   8.0s
# [CV] END clf__C=100, clf__class_weight=None, clf__solver=lbfgs; total time=   3.7s
# [CV] END clf__C=100, clf__class_weight=None, clf__solver=newton-cg; total time=   6.9s
# [CV] END clf__C=100, clf__class_weight=None, clf__solver=newton-cg; total time=   5.7s
# [CV] END clf__C=100, clf__class_weight=balanced, clf__solver=newton-cg; total time=   6.7s
# [CV] END clf__C=100, clf__class_weight=balanced, clf__solver=newton-cg; total time=   4.0s
# [CV] END clf__C=0.01, clf__class_weight=None, clf__solver=lbfgs; total time=   2.8s
# [CV] END clf__C=0.01, clf__class_weight=None, clf__solver=newton-cg; total time=   2.8s
# [CV] END clf__C=0.01, clf__class_weight=balanced, clf__solver=lbfgs; total time=   2.6s
# [CV] END clf__C=0.01, clf__class_weight=balanced, clf__solver=lbfgs; total time=   2.9s
# [CV] END clf__C=0.01, clf__class_weight=balanced, clf__solver=newton-cg; total time=   2.6s
# [CV] END clf__C=0.1, clf__class_weight=None, clf__solver=lbfgs; total time=   3.2s
# [CV] END clf__C=0.1, clf__class_weight=None, clf__solver=newton-cg; total time=   4.5s
# [CV] END clf__C=0.1, clf__class_weight=balanced, clf__solver=lbfgs; total time=   3.5s
# [CV] END clf__C=0.1, clf__class_weight=balanced, clf__solver=lbfgs; total time=   3.1s
# [CV] END clf__C=0.1, clf__class_weight=balanced, clf__solver=newton-cg; total time=   4.6s
# [CV] END clf__C=1, clf__class_weight=None, clf__solver=lbfgs; total time=   4.4s
# [CV] END clf__C=1, clf__class_weight=None, clf__solver=newton-cg; total time=   6.1s
# [CV] END clf__C=1, clf__class_weight=balanced, clf__solver=lbfgs; total time=   4.4s
# [CV] END clf__C=1, clf__class_weight=balanced, clf__solver=lbfgs; total time=   4.1s
# [CV] END clf__C=1, clf__class_weight=balanced, clf__solver=newton-cg; total time=   6.1s
# [CV] END clf__C=10, clf__class_weight=None, clf__solver=lbfgs; total time=   3.9s
# [CV] END clf__C=10, clf__class_weight=None, clf__solver=newton-cg; total time=   7.6s
# [CV] END clf__C=10, clf__class_weight=None, clf__solver=newton-cg; total time=   6.6s
# [CV] END clf__C=10, clf__class_weight=balanced, clf__solver=newton-cg; total time=   6.6s
# [CV] END clf__C=10, clf__class_weight=balanced, clf__solver=newton-cg; total time=   6.0s
# [CV] END clf__C=100, clf__class_weight=None, clf__solver=lbfgs; total time=   3.6s
# Mejores parámetros:
# {'clf__C': 100, 'clf__class_weight': 'balanced', 'clf__solver': 'lbfgs'}
#
# Mejor F1 Macro CV:
# 0.6863044711744914

# %%
best_lr = grid_lr.best_estimator_

yp_lr = best_lr.predict(X_te1)
ypr_lr = best_lr.predict_proba(X_te1)

met_lr = evaluar(
    'LR GridSearch',
    y_te1,
    yp_lr,
    ypr_lr
)
# Out:
# ══════════════════════════════════════════════════════════
#   LR GridSearch
# ══════════════════════════════════════════════════════════
#   Accuracy            : 0.6921
#   F1-score (macro)    : 0.6919
#   F1-score (weighted) : 0.6921
#   Precision (macro)   : 0.6919
#   Recall (macro)      : 0.6919
#   ROC-AUC             : 0.7641
#
# 📋 Classification Report:
#
#               precision    recall  f1-score   support
#
#            0       0.68      0.69      0.68     39640
#            1       0.70      0.70      0.70     41650
#
#     accuracy                           0.69     81290
#    macro avg       0.69      0.69      0.69     81290
# weighted avg       0.69      0.69      0.69     81290
#
#
# 📊 Matriz de Confusión (texto):
#
#         Pred_0  Pred_1
# Real_0   27178   12462
# Real_1   12570   29080

# %% [markdown]
# Los resultados obtenidos evidencian una mejora sustancial respecto al escenario multiclase. Esto era esperable, dado que la reducción del problema a dos categorías simplifica las fronteras de decisión y facilita la identificación de patrones relevantes en los datos sociodemográficos.
#
# El comportamiento equilibrado observado entre precisión y sensibilidad indica que el modelo mantiene un desempeño homogéneo sobre ambas clases, evitando sesgos significativos hacia alguna de ellas. Asimismo, el valor de ROC-AUC obtenido demuestra una adecuada capacidad de discriminación entre estudiantes pertenecientes a las dos categorías consideradas.
#
# En términos generales, los resultados muestran que la regresión logística constituye una alternativa efectiva para la predicción binaria del desempeño académico, proporcionando un equilibrio adecuado entre capacidad predictiva, simplicidad computacional e interpretabilidad. Por esta razón, la configuración obtenida mediante \textit{Grid Search}, con (C=100), \texttt{solver=lbfgs} y balanceo de clases activado, se selecciona como el modelo final para el escenario de clasificación binaria dentro de la familia de modelos de regresión logística.
